# %%
from pyspark.sql import functions as F

data1 = sqlContext.createDataFrame([
    (111,12,25,8),
    (112,13,24,11),
    (113,14,23,9),
    (114,15,24,12),
],["id","hour","temperature","wind"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(data1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>hour</th><th>temperature</th><th>wind</th></tr></thead><tbody><tr><td>111</td><td>12</td><td>25</td><td>8</td></tr><tr><td>112</td><td>13</td><td>24</td><td>11</td></tr><tr><td>113</td><td>14</td><td>23</td><td>9</td></tr><tr><td>114</td><td>15</td><td>24</td><td>12</td></tr></tbody></table></div>

# %%
data1.write.format("delta").saveAsTable("climate")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

DESCRIBE history climate
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
data2 = sqlContext.createDataFrame([
    (115,16,18,15),
    (116,17,17,23),
],["id","hour","temperature","wind"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data2.write.format("delta").mode("append").saveAsTable("climate")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

select * from climate
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>hour</th><th>temperature</th><th>wind</th></tr></thead><tbody><tr><td>111</td><td>12</td><td>25</td><td>8</td></tr><tr><td>112</td><td>13</td><td>24</td><td>11</td></tr><tr><td>113</td><td>14</td><td>23</td><td>9</td></tr><tr><td>114</td><td>15</td><td>24</td><td>12</td></tr><tr><td>115</td><td>16</td><td>18</td><td>15</td></tr><tr><td>116</td><td>17</td><td>17</td><td>23</td></tr></tbody></table></div>

# %%
# %sql

DESCRIBE history climate
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql

select * from climate VERSION AS OF 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>hour</th><th>temperature</th><th>wind</th></tr></thead><tbody><tr><td>111</td><td>12</td><td>25</td><td>8</td></tr><tr><td>112</td><td>13</td><td>24</td><td>11</td></tr><tr><td>113</td><td>14</td><td>23</td><td>9</td></tr><tr><td>114</td><td>15</td><td>24</td><td>12</td></tr><tr><td>115</td><td>16</td><td>18</td><td>15</td></tr><tr><td>116</td><td>17</td><td>17</td><td>23</td></tr></tbody></table></div>

# %%
df = spark.read.format("delta").option("versionAsOf", 1).load("dbfs:/user/hive/warehouse/climate")

df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----+-----------+----+
#  id|hour|temperature|wind|
# +---+----+-----------+----+
# 111|  12|         25|   8|
# 112|  13|         24|  11|
# 113|  14|         23|   9|
# 114|  15|         24|  12|
# 115|  16|         18|  15|
# 116|  17|         17|  23|
# +---+----+-----------+----+
#
# </div>
